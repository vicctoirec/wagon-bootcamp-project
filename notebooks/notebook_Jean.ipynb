# %%
# !ls
# Out:
# notebook_Jean.ipynb	notebook_Margaux.ipynb
# notebook_Laureen.ipynb	notebook_Victoire.ipynb

# %%
import pandas as pd

# %%
df = pd.read_csv("../raw_data/tcc_ceds_music.csv")

# %%
df.shape
# Out:
# (28372, 31)

# %%
df.query("artist_name=='johnny cash'")
# Out:
#        Unnamed: 0  artist_name                                    track_name  \
# 7068        20344  johnny cash                        the little drummer boy
# 7088        20382  johnny cash                               the loving gift
# 7102        20416  johnny cash                        tennessee flat top box
# 7111        20450  johnny cash                                all over again
# 7163        20574  johnny cash  i was there when it happened (2017 remaster)
# ...           ...          ...                                           ...
# 11546       35007  johnny cash                                 it's all over
# 11562       35071  johnny cash                             i came to believe
# 11565       35081  johnny cash                           a legend in my time
# 11854       36384  johnny cash                                ain't no grave
# 11872       36465  johnny cash                                redemption day
#
#        release_date    genre  \
# ...

# %%
df = pd.read_csv("../raw_data/database_20250606_1630.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                artist  \
# 0           0  Jean-Jacques Goldman
# 1           1  Jean-Jacques Goldman
# 2           2  Jean-Jacques Goldman
# 3           3  Jean-Jacques Goldman
# 4           4  Jean-Jacques Goldman
#
#                                           track_name  \
# 0        Je marche seul - Live Un tour ensemble 2002
# 1             Nos mains - Live Un tour ensemble 2002
# 2          Petite fille - Live Un tour ensemble 2002
# 3       Encore un matin - Live Un tour ensemble 2002
# 4  Je voudrais vous revoir - Live Un tour ensembl...
#
#                                               lyrics        track_title_clean  \
# 0  Comme un bateau dérive,\r\nSans but et sans mo...           Je marche seul
# 1  Sur une arme, les doigts noués.\rPour agresser...                Nos mains
# 2  Petite fille de Novembre,\rSi blanche dans la ...             Petite fille
# 3  Encore un matin,\rUn matin pour rien\rUne argi...          Encore un matin
# ...

# %%
d = df.sample(3)[['artist', 'track_name']].values.tolist()
d
# Out:
# [['Booba', 'RST'],
#  ['Jean-Louis Aubert', 'Sculpteur de vent'],
#  ['Niska', 'Moula']]

# %%
from ai_spotify_lyrics.model import initialize_dummy_model

# %%
model = initialize_dummy_model()

# %%
from ai_spotify_lyrics.params import DATA_CSV_INIT
DATA_CSV_INIT
# Out:
# '/home/jean/code/vicctoirec/wagon-bootcamp-project/raw_data/database_20250606_1630.csv'
